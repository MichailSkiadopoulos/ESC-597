# %% [markdown]
# IMPORT LIBRARIES

# %%
import numpy as np
import matplotlib.pyplot as plt
from google.colab import drive
import time
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import GridSearchCV
from xgboost import XGBRegressor
from sklearn.metrics import r2_score, mean_squared_error

# %% [markdown]
# MOUNT DRIVE

# %%
drive.mount('/content/drive/')
path = '/content/drive/My Drive/Colab Notebooks/ESC597/Tree-based methods/'
# Out:
# Mounted at /content/drive/

# %% [markdown]
# LOAD DATA

# %%
time_start = time.time()

filename = 'POROSITY'

xdf1 = np.loadtxt('{}{}_data1.txt'.format(path, filename)) #Time signals usesd as input to the ML
xdf2 = np.loadtxt('{}{}_data2.txt'.format(path, filename)) #Time signals usesd as input to the ML

ydf1 = np.loadtxt('{}{}_info1_reg.txt'.format(path, filename)) #Category Label vector
ydf2 = np.loadtxt('{}{}_info2_reg.txt'.format(path, filename)) #Category Label vector

xdf = np.concatenate((xdf1, xdf2), axis=0)

ydf = np.concatenate((ydf1[:,0], ydf2[:,0]), axis=0)

time_taken = time.time() - time_start
print('\nTotal time taken loading data (in seconds): {:.2f}'.format(time_taken))
# Out:
# Total time taken loading data (in seconds): 18.26

# %% [markdown]
# CREATE TRAIN AND TEST DATASETS

# %%
seed = 1234 #Define random seed for the shuffling of data
test_size = 0.2 #Define the percentage of testing data

X_train, X_test, y_train, y_test = train_test_split(xdf, ydf, test_size= test_size, random_state = seed, shuffle=True)

print("X_train Size:" + str(X_train.shape))
print("X_test Size:" + str(X_test.shape))

print("y_train Size:" + str(y_train.shape))
print("y_test Size:" + str(y_test.shape))
# Out:
# X_train Size:(1598, 3500)
# X_test Size:(400, 3500)
# y_train Size:(1598,)
# y_test Size:(400,)

# %% [markdown]
# SCALE THE DATA

# %%
scaler = MinMaxScaler((-1, 1))

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

scaler = MinMaxScaler((0, 1))

y_train = scaler.fit_transform(y_train.reshape(-1,1))
y_test = scaler.transform(y_test.reshape(-1,1))

# %% [markdown]
# DEFINE RANGES OF THE PARAMETERS TO PERFORM GRIDSEARCH FOR

# %%
# n_estimators: The number of trees/estimators to use.
# max_depth: The maximum depth of each tree / How much can the tree expand.
# learning_rate: value of The learning rate to be used for gradient descent during training
# subsample: Fraction of training data to choose from to form the input for each tree.
# colsample_bytree: Fraction of features to choose from to use for the regression rules in each tree.
# min_child_weight: The minimum sum of instance weight (hessian) needed in a node to split it.

model_params = {"n_estimators": [23, 103, 503],
                "max_depth": [2,],
                "learning_rate": [1e-2,],
                "subsample": [0.3],
                "colsample_bytree":[1.0,],
                "min_child_weight": [1.2,],
               }

# %% [markdown]
# INITIALIZE THE MODEL ΤΟ PERFORM THE GRID SEARCH OVER THE DEFINED RANGES OF THE DESIRED PARAMETERS

# %%
n_Kfolds = 5 # number of K-folds to consider fro cross-validation
model_GridSearch = XGBRegressor(random_state = seed,verbosity=2)
model_GridSearch = GridSearchCV(model_GridSearch, model_params, cv = n_Kfolds,verbose=1, scoring = "neg_mean_squared_error")
print(model_GridSearch)
# Out:
# GridSearchCV(cv=5,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None, gpu_id=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None, m...
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None, n_estimators=100,
#                                     n_jobs=None, num_parallel_tree=None,
#                                     predictor=None, random_state=1234, ...),
#              param_grid={'colsample_bytree': [1.0], 'learning_rate': [0.01],
#                          'max_depth': [2], 'min_child_weight': [1.2],
#                          'n_estimators': [23, 103, 503], 'subsample': [0.3]},
#              scoring='neg_mean_squared_error', verbose=1)

# %% [markdown]
# FIT THE MODEL

# %%
time_start = time.time()

model_GridSearch.fit(X_train, y_train) 

time_taken = time.time() - time_start
print('\nTotal time taken performing Grid Search (in seconds): {:.2f}'.format(time_taken))
# Out:
# Fitting 5 folds for each of 3 candidates, totalling 15 fits
# [17:38:09] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:09] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:09] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:10] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:10] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:10] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:10] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:10] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:10] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:10] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:11] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:11] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:11] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:11] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:11] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:11] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:11] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:11] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:12] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:12] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:12] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:12] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:12] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:13] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:13] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:13] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:13] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:13] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:13] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:13] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:14] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:14] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:14] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:14] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:14] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:14] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:14] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:15] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:15] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:15] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:15] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:15] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:15] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:15] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:15] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:16] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:16] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:17] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:17] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:17] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:18] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:18] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:18] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:19] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:19] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:19] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:20] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:20] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:20] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:20] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:20] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:20] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:21] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:21] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:21] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:21] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:21] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:21] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:21] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:22] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:22] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:22] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:22] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:22] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:23] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:23] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:23] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:23] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:23] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:23] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:23] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:23] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:24] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:24] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:24] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:24] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:24] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:24] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:24] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:24] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:25] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:25] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:25] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:25] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:26] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:26] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:26] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:26] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:26] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:26] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:26] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:26] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:27] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:27] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:27] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:27] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:27] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:27] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:27] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:27] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:28] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:28] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:28] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:28] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:28] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:29] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:29] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:29] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:29] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:29] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:29] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:29] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:30] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:30] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:30] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:30] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:30] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:30] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:30] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:31] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:31] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:31] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:32] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:32] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:32] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:32] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:33] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:33] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:33] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:34] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:34] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:34] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:34] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:35] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:35] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:35] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:35] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:35] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:35] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:35] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:35] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:36] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:36] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:36] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:36] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:36] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:36] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:36] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:37] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:37] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:37] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:37] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:37] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:37] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:37] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:37] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:38] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:38] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:38] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:38] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:38] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:38] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:38] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:39] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:39] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:39] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:39] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:39] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:39] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:39] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:39] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:40] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:40] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:40] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:40] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:40] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:40] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:40] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:40] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:41] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:41] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:41] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:41] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:41] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:41] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:41] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:42] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:42] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:42] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:42] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:42] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:42] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:42] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:42] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:43] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:43] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:43] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:43] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:43] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:43] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:43] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:43] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:46] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:46] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:46] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:47] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:47] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:47] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:47] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:48] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:48] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:48] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:49] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:49] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:49] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:49] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:49] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:49] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:49] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:49] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:50] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:50] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:50] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:50] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:50] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:50] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:50] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:50] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:51] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:51] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:51] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:51] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:51] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:51] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:51] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:52] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:52] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:52] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:52] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:52] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:52] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:52] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:52] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:53] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:53] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:53] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:53] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:53] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:53] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:53] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:53] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:54] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:54] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:54] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:54] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:54] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:54] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:54] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:55] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:55] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:55] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:55] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:55] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:55] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:55] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:55] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:56] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:56] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:56] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:56] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:56] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:56] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:56] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:56] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:57] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:57] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:57] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:57] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:57] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:57] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:57] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:57] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:58] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:58] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:58] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:58] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:58] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:58] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:58] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:58] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:59] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:59] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:59] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:38:59] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:00] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:00] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:00] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:00] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:01] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:01] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:01] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:02] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:02] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:03] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:03] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:03] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:03] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:03] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:04] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:04] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:04] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:04] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:04] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:04] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:04] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:04] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:05] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:05] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:05] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:05] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:05] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:05] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:05] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:06] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:06] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:06] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:06] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:06] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:06] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:06] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:06] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:07] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:07] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:07] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:07] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:07] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:07] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:07] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:07] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:08] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:08] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:08] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:08] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:08] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:08] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:08] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:09] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:09] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:09] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:09] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:09] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:09] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:09] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:09] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:10] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:10] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:10] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:10] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:10] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:10] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:10] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:10] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:11] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:11] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:11] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:11] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:11] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:11] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:11] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:11] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:12] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:12] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:12] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:12] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:12] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:12] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:12] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:13] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:13] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:13] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:13] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:13] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:13] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:14] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:14] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:14] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:14] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:15] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:15] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:15] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:15] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:16] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:16] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:16] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:16] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:17] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:17] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:17] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:17] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:18] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:18] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:18] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:18] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:18] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:18] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:18] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:19] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:19] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:19] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:19] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:20] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:20] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:39:20] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# ...
# [17:47:33] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:34] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:34] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:34] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:35] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:35] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:35] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:36] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:36] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:36] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:37] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:37] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:37] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:37] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:37] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:37] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:38] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:38] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:38] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:38] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:38] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:38] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:38] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:39] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:39] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:39] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:39] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:39] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:39] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:40] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:40] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 4 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:40] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:40] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:40] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:40] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:41] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:41] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:41] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:41] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:41] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:41] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:41] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:42] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:42] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:42] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:42] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:42] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:42] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:43] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:43] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:43] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:43] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:43] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:43] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:44] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:45] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:46] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:46] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:46] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:46] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:46] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:46] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:47] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:47] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:47] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:47] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:48] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:48] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:48] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:49] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:49] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:49] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:50] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:50] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:50] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:51] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:51] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:51] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:51] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:52] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:52] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:52] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:52] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:52] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:52] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:53] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:53] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:53] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:53] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:53] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:53] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:53] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:54] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:54] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:54] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:54] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:54] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:54] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:55] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:55] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:55] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:55] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:55] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:55] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:56] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:56] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:56] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:56] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:56] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:56] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:56] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:57] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:57] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:57] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:57] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:57] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:57] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:58] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:58] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:58] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:58] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:58] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:58] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:59] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:59] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:59] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:59] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:59] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:59] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:47:59] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:48:00] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
# [17:48:00] INFO: ../src/tree/updater_prune.cc:98: tree pruning end, 6 extra nodes, 0 pruned nodes, max_depth=2
#
# Total time taken performing Grid Search (in seconds): 591.25

# %% [markdown]
# PRINT THE PARAMETERS OF THE BEST MODEL THAT WAS GIVEN FROM GRIDSEARCH

# %%
best_estimator = model_GridSearch.best_estimator_ # get the best model
best_score = model_GridSearch.best_score_ # get the score for the best estimator
best_parameters = model_GridSearch.best_params_ # get the parameters for the best estimator

print(" Results from Grid Search " )
print("\n The best estimator across ALL searched params:\n", best_estimator)
print("\n The best score across ALL searched params:\n", best_score)
print("\n The best parameters across ALL searched params:\n", best_parameters)
# Out:
#  Results from Grid Search
#
#  The best estimator across ALL searched params:
#  XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=1.0, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=0.01, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=2, max_leaves=None,
#              min_child_weight=1.2, missing=nan, monotone_constraints=None,
#              n_estimators=503, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=1234, ...)
#
#  The best score across ALL searched params:
#  -0.022219127881528206
#
#  The best parameters across ALL searched params:
#  {'colsample_bytree': 1.0, 'learning_rate': 0.01, 'max_depth': 2, 'min_child_weight': 1.2, 'n_estimators': 503, 'subsample': 0.3}

# %% [markdown]
# PLOT THE GRIDSEARCH RESULTS

# %%
name_param_1 = "n_estimators"
name_param_2 = "max_depth"

grid_param_1 = model_params["n_estimators"]
grid_param_2 = model_params["max_depth"]

scores_mean = -model_GridSearch.cv_results_['mean_test_score']
scores_mean = np.array(scores_mean).reshape(len(grid_param_2),len(grid_param_1))

# Plot Grid search scores
_, ax = plt.subplots(1,1)

# Param1 is the X-axis, Param 2 is represented as a different curve (color line)
for idx, val in enumerate(grid_param_2):
    ax.plot(grid_param_1, scores_mean[idx,:], '-o', label= name_param_2 + ': ' + str(val))

ax.set_title("Grid Search Scores", fontsize=20, fontweight='bold')
ax.set_xlabel(name_param_1, fontsize=16)
ax.set_ylabel('CV Average RMSE', fontsize=16)
ax.legend(loc="best", fontsize=15)
ax.grid('on')

plt.savefig("convergence.jpg", dpi=400)

# %% [markdown]
# INITIALIZE AND FIT THE MODEL WITH THE BEST PARAMETERS

# %%
time_start = time.time()

#model = XGBRegressor(**best_parameters)

model = XGBRegressor(colsample_bytree = 1.0, subsample = 0.3, learning_rate = 1e-2, max_depth = 2, min_child_weight = 1.2, n_estimators = 503, random_state = seed,verbose=1)

model.fit(X_train, y_train, eval_set=[(X_train, y_train)], verbose=True)#, eval_metric = 'rmse', early_stopping_rounds=3, verbose=True) 

time_taken = time.time() - time_start
print('\nTotal time taken fitting the model (in seconds): {:.2f}'.format(time_taken))
# Out:
# [13:13:04] WARNING: ../src/learner.cc:767:
# Parameters: { "verbose" } are not used.
#
# [0]	validation_0-rmse:0.28678
# [1]	validation_0-rmse:0.28527
# [2]	validation_0-rmse:0.28388
# [3]	validation_0-rmse:0.28262
# [4]	validation_0-rmse:0.28139
# [5]	validation_0-rmse:0.28007
# [6]	validation_0-rmse:0.27871
# [7]	validation_0-rmse:0.27737
# [8]	validation_0-rmse:0.27594
# [9]	validation_0-rmse:0.27465
# [10]	validation_0-rmse:0.27354
# [11]	validation_0-rmse:0.27246
# [12]	validation_0-rmse:0.27132
# [13]	validation_0-rmse:0.27007
# [94]	validation_0-rmse:0.20762
# [95]	validation_0-rmse:0.20713
# [96]	validation_0-rmse:0.20662
# [97]	validation_0-rmse:0.20621
# [98]	validation_0-rmse:0.20571
# [99]	validation_0-rmse:0.20515
# [100]	validation_0-rmse:0.20459
# [101]	validation_0-rmse:0.20402
# [102]	validation_0-rmse:0.20345
# [103]	validation_0-rmse:0.20289
# [104]	validation_0-rmse:0.20250
# [105]	validation_0-rmse:0.20200
# [106]	validation_0-rmse:0.20153
# [107]	validation_0-rmse:0.20101
# [108]	validation_0-rmse:0.20050
# [109]	validation_0-rmse:0.20006
# [110]	validation_0-rmse:0.19950
# [111]	validation_0-rmse:0.19915
# [112]	validation_0-rmse:0.19874
# [113]	validation_0-rmse:0.19832
# [114]	validation_0-rmse:0.19786
# [115]	validation_0-rmse:0.19751
# [116]	validation_0-rmse:0.19702
# [117]	validation_0-rmse:0.19657
# [118]	validation_0-rmse:0.19624
# [119]	validation_0-rmse:0.19583
# [120]	validation_0-rmse:0.19550
# [121]	validation_0-rmse:0.19503
# [122]	validation_0-rmse:0.19458
# [123]	validation_0-rmse:0.19414
# [124]	validation_0-rmse:0.19385
# [125]	validation_0-rmse:0.19350
# [126]	validation_0-rmse:0.19312
# [127]	validation_0-rmse:0.19276
# [128]	validation_0-rmse:0.19233
# [129]	validation_0-rmse:0.19195
# [130]	validation_0-rmse:0.19157
# [131]	validation_0-rmse:0.19120
# [132]	validation_0-rmse:0.19088
# [133]	validation_0-rmse:0.19052
# [134]	validation_0-rmse:0.19006
# [135]	validation_0-rmse:0.18967
# [136]	validation_0-rmse:0.18931
# [137]	validation_0-rmse:0.18890
# [138]	validation_0-rmse:0.18846
# [139]	validation_0-rmse:0.18818
# [140]	validation_0-rmse:0.18783
# [141]	validation_0-rmse:0.18746
# [142]	validation_0-rmse:0.18718
# [143]	validation_0-rmse:0.18682
# [144]	validation_0-rmse:0.18652
# [145]	validation_0-rmse:0.18624
# [146]	validation_0-rmse:0.18587
# [147]	validation_0-rmse:0.18563
# [148]	validation_0-rmse:0.18529
# [149]	validation_0-rmse:0.18500
# [150]	validation_0-rmse:0.18472
# [151]	validation_0-rmse:0.18436
# [152]	validation_0-rmse:0.18406
# [153]	validation_0-rmse:0.18374
# [154]	validation_0-rmse:0.18340
# [155]	validation_0-rmse:0.18317
# [156]	validation_0-rmse:0.18285
# [157]	validation_0-rmse:0.18258
# [158]	validation_0-rmse:0.18224
# [159]	validation_0-rmse:0.18185
# [160]	validation_0-rmse:0.18151
# [161]	validation_0-rmse:0.18128
# [162]	validation_0-rmse:0.18098
# [163]	validation_0-rmse:0.18071
# [164]	validation_0-rmse:0.18044
# [165]	validation_0-rmse:0.18014
# [166]	validation_0-rmse:0.17978
# [167]	validation_0-rmse:0.17956
# [168]	validation_0-rmse:0.17929
# [169]	validation_0-rmse:0.17907
# [170]	validation_0-rmse:0.17883
# [171]	validation_0-rmse:0.17865
# [172]	validation_0-rmse:0.17842
# [173]	validation_0-rmse:0.17815
# [254]	validation_0-rmse:0.16153
# [255]	validation_0-rmse:0.16134
# [256]	validation_0-rmse:0.16117
# [257]	validation_0-rmse:0.16100
# [258]	validation_0-rmse:0.16085
# [259]	validation_0-rmse:0.16067
# [260]	validation_0-rmse:0.16053
# [261]	validation_0-rmse:0.16037
# [262]	validation_0-rmse:0.16020
# [263]	validation_0-rmse:0.16006
# [264]	validation_0-rmse:0.15988
# [265]	validation_0-rmse:0.15972
# [266]	validation_0-rmse:0.15956
# [267]	validation_0-rmse:0.15943
# [268]	validation_0-rmse:0.15927
# [269]	validation_0-rmse:0.15908
# [270]	validation_0-rmse:0.15895
# [271]	validation_0-rmse:0.15878
# [272]	validation_0-rmse:0.15863
# [273]	validation_0-rmse:0.15843
# [274]	validation_0-rmse:0.15828
# [275]	validation_0-rmse:0.15816
# [276]	validation_0-rmse:0.15800
# [277]	validation_0-rmse:0.15785
# [278]	validation_0-rmse:0.15769
# [279]	validation_0-rmse:0.15756
# [280]	validation_0-rmse:0.15742
# [281]	validation_0-rmse:0.15726
# [282]	validation_0-rmse:0.15712
# [283]	validation_0-rmse:0.15694
# [284]	validation_0-rmse:0.15680
# [285]	validation_0-rmse:0.15670
# [286]	validation_0-rmse:0.15658
# [287]	validation_0-rmse:0.15640
# [288]	validation_0-rmse:0.15624
# [289]	validation_0-rmse:0.15611
# [290]	validation_0-rmse:0.15595
# [291]	validation_0-rmse:0.15578
# [292]	validation_0-rmse:0.15569
# [293]	validation_0-rmse:0.15552
# [294]	validation_0-rmse:0.15538
# [295]	validation_0-rmse:0.15522
# [296]	validation_0-rmse:0.15508
# [297]	validation_0-rmse:0.15494
# [298]	validation_0-rmse:0.15480
# [299]	validation_0-rmse:0.15467
# [300]	validation_0-rmse:0.15454
# [301]	validation_0-rmse:0.15439
# [302]	validation_0-rmse:0.15428
# [303]	validation_0-rmse:0.15416
# [304]	validation_0-rmse:0.15402
# [305]	validation_0-rmse:0.15388
# [306]	validation_0-rmse:0.15374
# [307]	validation_0-rmse:0.15356
# [308]	validation_0-rmse:0.15344
# [309]	validation_0-rmse:0.15333
# [310]	validation_0-rmse:0.15319
# [311]	validation_0-rmse:0.15300
# [312]	validation_0-rmse:0.15286
# [313]	validation_0-rmse:0.15277
# [314]	validation_0-rmse:0.15263
# [315]	validation_0-rmse:0.15250
# [316]	validation_0-rmse:0.15233
# [317]	validation_0-rmse:0.15219
# [318]	validation_0-rmse:0.15206
# [319]	validation_0-rmse:0.15192
# [320]	validation_0-rmse:0.15182
# [321]	validation_0-rmse:0.15170
# [322]	validation_0-rmse:0.15157
# [323]	validation_0-rmse:0.15149
# [324]	validation_0-rmse:0.15136
# [325]	validation_0-rmse:0.15127
# [326]	validation_0-rmse:0.15114
# [327]	validation_0-rmse:0.15097
# [328]	validation_0-rmse:0.15081
# [329]	validation_0-rmse:0.15068
# [330]	validation_0-rmse:0.15057
# [331]	validation_0-rmse:0.15047
# [332]	validation_0-rmse:0.15035
# [333]	validation_0-rmse:0.15022
# [334]	validation_0-rmse:0.15010
# [335]	validation_0-rmse:0.14999
# [336]	validation_0-rmse:0.14986
# [337]	validation_0-rmse:0.14977
# [338]	validation_0-rmse:0.14960
# [339]	validation_0-rmse:0.14948
# [340]	validation_0-rmse:0.14935
# [341]	validation_0-rmse:0.14925
# [342]	validation_0-rmse:0.14916
# [343]	validation_0-rmse:0.14905
# [344]	validation_0-rmse:0.14894
# [345]	validation_0-rmse:0.14881
# [346]	validation_0-rmse:0.14870
# [347]	validation_0-rmse:0.14855
# [348]	validation_0-rmse:0.14844
# [349]	validation_0-rmse:0.14832
# [350]	validation_0-rmse:0.14822
# [351]	validation_0-rmse:0.14811
# [352]	validation_0-rmse:0.14797
# [353]	validation_0-rmse:0.14783
# [354]	validation_0-rmse:0.14773
# [355]	validation_0-rmse:0.14760
# [356]	validation_0-rmse:0.14749
# [357]	validation_0-rmse:0.14739
# [358]	validation_0-rmse:0.14729
# [359]	validation_0-rmse:0.14719
# [360]	validation_0-rmse:0.14705
# [361]	validation_0-rmse:0.14692
# [362]	validation_0-rmse:0.14681
# [363]	validation_0-rmse:0.14667
# [364]	validation_0-rmse:0.14657
# [365]	validation_0-rmse:0.14643
# [366]	validation_0-rmse:0.14631
# [367]	validation_0-rmse:0.14619
# [368]	validation_0-rmse:0.14608
# [369]	validation_0-rmse:0.14597
# [370]	validation_0-rmse:0.14589
# [371]	validation_0-rmse:0.14576
# [372]	validation_0-rmse:0.14563
# [373]	validation_0-rmse:0.14553
# [374]	validation_0-rmse:0.14542
# [375]	validation_0-rmse:0.14533
# [376]	validation_0-rmse:0.14523
# [377]	validation_0-rmse:0.14511
# [378]	validation_0-rmse:0.14498
# [379]	validation_0-rmse:0.14487
# [380]	validation_0-rmse:0.14481
# [381]	validation_0-rmse:0.14470
# [382]	validation_0-rmse:0.14457
# [383]	validation_0-rmse:0.14446
# [384]	validation_0-rmse:0.14435
# [385]	validation_0-rmse:0.14426
# [386]	validation_0-rmse:0.14413
# [387]	validation_0-rmse:0.14403
# [388]	validation_0-rmse:0.14393
# [389]	validation_0-rmse:0.14382
# [390]	validation_0-rmse:0.14373
# [391]	validation_0-rmse:0.14363
# [392]	validation_0-rmse:0.14352
# [393]	validation_0-rmse:0.14344
# [394]	validation_0-rmse:0.14335
# [395]	validation_0-rmse:0.14325
# [396]	validation_0-rmse:0.14319
# [397]	validation_0-rmse:0.14309
# [398]	validation_0-rmse:0.14299
# [399]	validation_0-rmse:0.14289
# [400]	validation_0-rmse:0.14278
# [401]	validation_0-rmse:0.14268
# [402]	validation_0-rmse:0.14256
# [403]	validation_0-rmse:0.14246
# [404]	validation_0-rmse:0.14237
# [405]	validation_0-rmse:0.14228
# [406]	validation_0-rmse:0.14216
# [407]	validation_0-rmse:0.14209
# [408]	validation_0-rmse:0.14198
# [409]	validation_0-rmse:0.14192
# [410]	validation_0-rmse:0.14181
# [411]	validation_0-rmse:0.14170
# [412]	validation_0-rmse:0.14160
# [413]	validation_0-rmse:0.14151
# [414]	validation_0-rmse:0.14142
# [415]	validation_0-rmse:0.14132
# [416]	validation_0-rmse:0.14119
# [417]	validation_0-rmse:0.14109
# [418]	validation_0-rmse:0.14099
# [419]	validation_0-rmse:0.14087
# [420]	validation_0-rmse:0.14076
# [421]	validation_0-rmse:0.14067
# [422]	validation_0-rmse:0.14059
# [423]	validation_0-rmse:0.14047
# [424]	validation_0-rmse:0.14039
# [425]	validation_0-rmse:0.14028
# [426]	validation_0-rmse:0.14017
# [427]	validation_0-rmse:0.14007
# [428]	validation_0-rmse:0.13999
# [429]	validation_0-rmse:0.13989
# [430]	validation_0-rmse:0.13979
# [431]	validation_0-rmse:0.13971
# [432]	validation_0-rmse:0.13961
# [433]	validation_0-rmse:0.13954
# [434]	validation_0-rmse:0.13945
# [435]	validation_0-rmse:0.13937
# [436]	validation_0-rmse:0.13925
# [437]	validation_0-rmse:0.13917
# [438]	validation_0-rmse:0.13908
# [439]	validation_0-rmse:0.13900
# [440]	validation_0-rmse:0.13892
# [441]	validation_0-rmse:0.13882
# [442]	validation_0-rmse:0.13871
# [443]	validation_0-rmse:0.13862
# [444]	validation_0-rmse:0.13853
# [445]	validation_0-rmse:0.13844
# [446]	validation_0-rmse:0.13836
# [447]	validation_0-rmse:0.13827
# [448]	validation_0-rmse:0.13820
# [449]	validation_0-rmse:0.13809
# [450]	validation_0-rmse:0.13800
# [451]	validation_0-rmse:0.13792
# [452]	validation_0-rmse:0.13782
# [453]	validation_0-rmse:0.13774
# [454]	validation_0-rmse:0.13767
# [455]	validation_0-rmse:0.13759
# [456]	validation_0-rmse:0.13751
# [457]	validation_0-rmse:0.13741
# [458]	validation_0-rmse:0.13734
# [459]	validation_0-rmse:0.13726
# [460]	validation_0-rmse:0.13718
# [461]	validation_0-rmse:0.13710
# [462]	validation_0-rmse:0.13702
# [463]	validation_0-rmse:0.13695
# [464]	validation_0-rmse:0.13686
# [465]	validation_0-rmse:0.13678
# [466]	validation_0-rmse:0.13670
# [467]	validation_0-rmse:0.13661
# [468]	validation_0-rmse:0.13653
# [469]	validation_0-rmse:0.13644
# [470]	validation_0-rmse:0.13636
# [471]	validation_0-rmse:0.13627
# [472]	validation_0-rmse:0.13618
# [473]	validation_0-rmse:0.13609
# [474]	validation_0-rmse:0.13602
# [475]	validation_0-rmse:0.13591
# [476]	validation_0-rmse:0.13584
# [477]	validation_0-rmse:0.13574
# [478]	validation_0-rmse:0.13566
# [479]	validation_0-rmse:0.13557
# [480]	validation_0-rmse:0.13550
# [481]	validation_0-rmse:0.13544
# [482]	validation_0-rmse:0.13537
# [483]	validation_0-rmse:0.13529
# [484]	validation_0-rmse:0.13523
# [485]	validation_0-rmse:0.13515
# [486]	validation_0-rmse:0.13505
# [487]	validation_0-rmse:0.13496
# [488]	validation_0-rmse:0.13489
# [489]	validation_0-rmse:0.13482
# [490]	validation_0-rmse:0.13473
# [491]	validation_0-rmse:0.13467
# [492]	validation_0-rmse:0.13461
# [493]	validation_0-rmse:0.13453
# [494]	validation_0-rmse:0.13441
# [495]	validation_0-rmse:0.13432
# [496]	validation_0-rmse:0.13424
# [497]	validation_0-rmse:0.13418
# [498]	validation_0-rmse:0.13407
# [499]	validation_0-rmse:0.13400
# [500]	validation_0-rmse:0.13391
# [501]	validation_0-rmse:0.13383
# [502]	validation_0-rmse:0.13374
#
# Total time taken fitting the model (in seconds): 110.86

# %% [markdown]
# PRINT THE OPTIMAL NUMBER OF TREES

# %%
number = model.best_ntree_limit
print(number)
# Out:
# 503

# %% [markdown]
# PLOT MODEL'S CONVERGENCE WITH INCREASING NUMBER OF TREES

# %%
results = model.evals_result()

plt.figure(figsize=(10,7))
plt.plot(results["validation_0"]["rmse"], label="Training loss")
plt.axvline(number-1, color="gray", label="Optimal tree number")
plt.xlabel("Number of trees")
plt.ylabel("Loss")
plt.legend()

# %% [markdown]
# CALCULATE TRAINING AND TESTING RMSE VALUES

# %%
# Training
predictions_train = model.predict(X_train)
RMSE_train = np.sqrt(mean_squared_error(y_train, predictions_train))
print("RMSE scores: Train - %0.2f" %(RMSE_train))

# Testing
predictions_test = model.predict(X_test)
RMSE_test = np.sqrt(mean_squared_error(y_test, predictions_test))
print("RMSE scores: Testing - %0.2f" %(RMSE_test))
# Out:
# RMSE scores: Train - 0.13
# RMSE scores: Testing - 0.15

# %% [markdown]
# CALCULATE TRAINING AND TESTING R2-SCORE VALUES

# %%
# Training
r2_train = r2_score(y_train, predictions_train)
print("R2 scores: Train - %0.2f" %(r2_train))

predictions_train =  predictions_train.reshape(-1, 1)

plt.figure(0)
plt.plot(scaler.inverse_transform(y_train), scaler.inverse_transform(predictions_train), 'o')
plt.plot([min(scaler.inverse_transform(y_train)), max(scaler.inverse_transform(y_train))], [min(scaler.inverse_transform(y_train)), max(scaler.inverse_transform(y_train))], '-')
plt.xlabel("True value")
plt.ylabel("Predictions")
plt.title("Training dataset")
plt.savefig("Training.jpg", dpi=400)

# Testing
r2_test = r2_score(y_test, predictions_test)
print("R2 scores: Testing - %0.2f" %(r2_test))

predictions_test = predictions_test.reshape(-1, 1)

plt.figure(1)
plt.plot(scaler.inverse_transform(y_test), scaler.inverse_transform(predictions_test), 'o')
plt.plot([min(scaler.inverse_transform(y_test)), max(scaler.inverse_transform(y_test))], [min(scaler.inverse_transform(y_test)), max(scaler.inverse_transform(y_test))], '-')
plt.xlabel("True value")
plt.ylabel("Predictions")
plt.title("Testing dataset")
plt.savefig("Testing.jpg", dpi=400)
# Out:
# R2 scores: Train - 0.78
# R2 scores: Testing - 0.75

# %% [markdown]
# Calculate feature importance

# %%
##
importance_porosity = model.feature_importances_
importance_porosity = importance_porosity / max(importance_porosity)
most_important_features_porosity = np.argmax(importance_porosity)

plt.figure(0)
plt.plot(np.linspace(0, int(X_train.shape[1]), int(X_train.shape[1]), dtype = int), importance_porosity)
plt.xlabel("Feauture")
plt.ylabel("Importance")
plt.title("Importance for porosity")
##

##
plt.figure(1)
plt.scatter(np.linspace(0, int(X_train.shape[1]), int(X_train.shape[1]), dtype = int), xdf[-1], c= importance_porosity,  cmap = 'jet')
plt.xlabel("Feauture")
plt.ylabel("Amplitude")
plt.title("Importance for porosity")
plt.colorbar()
##
